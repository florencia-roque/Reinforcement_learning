# %% [markdown]
# # TAR: Taller de Aprendizaje por Refuerzo 2025
# ## Laboratorio 4: Introdución a Gymnasium
# ### ¿Qué es Gymnasium?
#
# **Gymnasium** es una librería ampliamente utilizada en el campo del aprendizaje por refuerzos. Proporciona una colección de entornos estandarizados, como simulaciones de juegos, tareas físicas y otros desafíos, que nos permiten evaluar y entrenar agentes en una variedad de escenarios. La simplicidad y flexibilidad de Gymnasium lo convierten en una herramienta ampliamente utilizada. Documentación https://gymnasium.farama.org/index.html

# %% [markdown]
# *Ejecutar esta celda solo la primera vez (si estan usando un entorno local) para descargar e instalar los paquetes necesarios. Si ejecutan el notebook en colab tendran que ejecutarla cada vez que reinicien el kernel*

# %%
import subprocess

print(subprocess.run(["cmake", "--version"], capture_output=True).stdout.decode())
print(subprocess.run(["swig", "-version"], capture_output=True).stdout.decode())
# Out:
# cmake version 4.0.2
#
# CMake suite maintained and supported by Kitware (kitware.com/cmake).
#
#
# SWIG Version 4.3.1
#
# Compiled with x86_64-w64-mingw32-g++ [x86_64-w64-mingw32]
#
# Configured options: +pcre
#
# Please see https://www.swig.org for reporting bugs and further information

# %%
# !pip install Box2D
# Out:
# Collecting Box2D
#   Downloading Box2D-2.3.10-cp311-cp311-win_amd64.whl.metadata (593 bytes)
# Downloading Box2D-2.3.10-cp311-cp311-win_amd64.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------  1.3/1.3 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.3/1.3 MB 6.1 MB/s eta 0:00:00
# Installing collected packages: Box2D
# Successfully installed Box2D-2.3.10

# %%
import Box2D
print(Box2D.__version__)
# Out:
# 2.3.10

# %%
# !pip install gymnasium
# Out:
# Collecting gymnasium
#   Using cached gymnasium-1.1.1-py3-none-any.whl.metadata (9.4 kB)
# Collecting numpy>=1.21.0 (from gymnasium)
#   Using cached numpy-2.3.0-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Collecting cloudpickle>=1.2.0 (from gymnasium)
#   Using cached cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\flopa\miniconda3\envs\tar\lib\site-packages (from gymnasium) (4.12.2)
# Collecting farama-notifications>=0.0.1 (from gymnasium)
#   Using cached Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Using cached gymnasium-1.1.1-py3-none-any.whl (965 kB)
# Using cached cloudpickle-3.1.1-py3-none-any.whl (20 kB)
# Using cached Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Using cached numpy-2.3.0-cp311-cp311-win_amd64.whl (13.0 MB)
# Installing collected packages: farama-notifications, numpy, cloudpickle, gymnasium
#
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    ---------- ----------------------------- 1/4 [numpy]
#    -------------------- ------------------- 2/4 [cloudpickle]
#    ------------------------------ --------- 3/4 [gymnasium]
#    ------------------------------ --------- 3/4 [gymnasium]
#    ------------------------------ --------- 3/4 [gymnasium]
#    ------------------------------ --------- 3/4 [gymnasium]
#    ------------------------------ --------- 3/4 [gymnasium]
#    ------------------------------ --------- 3/4 [gymnasium]
#    ------------------------------ --------- 3/4 [gymnasium]
#    ------------------------------ --------- 3/4 [gymnasium]
#    ------------------------------ --------- 3/4 [gymnasium]
#    ------------------------------ --------- 3/4 [gymnasium]
#    ------------------------------ --------- 3/4 [gymnasium]
#    ------------------------------ --------- 3/4 [gymnasium]
#    ---------------------------------------- 4/4 [gymnasium]
#
# Successfully installed cloudpickle-3.1.1 farama-notifications-0.0.4 gymnasium-1.1.1 numpy-2.3.0

# %%
# !pip install pygame --only-binary :all:
# Out:
# Collecting pygame
#   Using cached pygame-2.6.1-cp311-cp311-win_amd64.whl.metadata (13 kB)
# Using cached pygame-2.6.1-cp311-cp311-win_amd64.whl (10.6 MB)
# Installing collected packages: pygame
# Successfully installed pygame-2.6.1

# %%
# !pip install stable-baselines3==2.0.0a5 huggingface_sb3 swig
# Out:
# Collecting stable-baselines3==2.0.0a5
#   Using cached stable_baselines3-2.0.0a5-py3-none-any.whl.metadata (5.3 kB)
# Collecting huggingface_sb3
#   Using cached huggingface_sb3-3.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting swig
#   Using cached swig-4.3.1-py3-none-win_amd64.whl.metadata (3.5 kB)
# Collecting gymnasium==0.28.1 (from stable-baselines3==2.0.0a5)
#   Using cached gymnasium-0.28.1-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: numpy in c:\users\flopa\miniconda3\envs\tar\lib\site-packages (from stable-baselines3==2.0.0a5) (2.3.0)
# Collecting torch>=1.11 (from stable-baselines3==2.0.0a5)
#   Using cached torch-2.7.1-cp311-cp311-win_amd64.whl.metadata (28 kB)
# Requirement already satisfied: cloudpickle in c:\users\flopa\miniconda3\envs\tar\lib\site-packages (from stable-baselines3==2.0.0a5) (3.1.1)
# Collecting pandas (from stable-baselines3==2.0.0a5)
#   Using cached pandas-2.3.0-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Collecting matplotlib (from stable-baselines3==2.0.0a5)
#   Using cached matplotlib-3.10.3-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Collecting jax-jumpy>=1.0.0 (from gymnasium==0.28.1->stable-baselines3==2.0.0a5)
#   Using cached jax_jumpy-1.0.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\flopa\miniconda3\envs\tar\lib\site-packages (from gymnasium==0.28.1->stable-baselines3==2.0.0a5) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\flopa\miniconda3\envs\tar\lib\site-packages (from gymnasium==0.28.1->stable-baselines3==2.0.0a5) (0.0.4)
# Collecting huggingface-hub~=0.8 (from huggingface_sb3)
#   Using cached huggingface_hub-0.33.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: pyyaml~=6.0 in c:\users\flopa\miniconda3\envs\tar\lib\site-packages (from huggingface_sb3) (6.0.2)
# Collecting wasabi (from huggingface_sb3)
#   Using cached wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting filelock (from huggingface-hub~=0.8->huggingface_sb3)
#   Using cached filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub~=0.8->huggingface_sb3)
#   Using cached fsspec-2025.5.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=20.9 in c:\users\flopa\appdata\roaming\python\python311\site-packages (from huggingface-hub~=0.8->huggingface_sb3) (23.1)
# Requirement already satisfied: requests in c:\users\flopa\miniconda3\envs\tar\lib\site-packages (from huggingface-hub~=0.8->huggingface_sb3) (2.32.3)
# Collecting tqdm>=4.42.1 (from huggingface-hub~=0.8->huggingface_sb3)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting sympy>=1.13.3 (from torch>=1.11->stable-baselines3==2.0.0a5)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch>=1.11->stable-baselines3==2.0.0a5)
#   Using cached networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: jinja2 in c:\users\flopa\miniconda3\envs\tar\lib\site-packages (from torch>=1.11->stable-baselines3==2.0.0a5) (3.1.6)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch>=1.11->stable-baselines3==2.0.0a5)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: colorama in c:\users\flopa\appdata\roaming\python\python311\site-packages (from tqdm>=4.42.1->huggingface-hub~=0.8->huggingface_sb3) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\flopa\miniconda3\envs\tar\lib\site-packages (from jinja2->torch>=1.11->stable-baselines3==2.0.0a5) (3.0.2)
# Collecting contourpy>=1.0.1 (from matplotlib->stable-baselines3==2.0.0a5)
#   Using cached contourpy-1.3.2-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib->stable-baselines3==2.0.0a5)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->stable-baselines3==2.0.0a5)
#   Using cached fonttools-4.58.2-cp311-cp311-win_amd64.whl.metadata (108 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->stable-baselines3==2.0.0a5)
#   Using cached kiwisolver-1.4.8-cp311-cp311-win_amd64.whl.metadata (6.3 kB)
# Collecting pillow>=8 (from matplotlib->stable-baselines3==2.0.0a5)
#   Using cached pillow-11.2.1-cp311-cp311-win_amd64.whl.metadata (9.1 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib->stable-baselines3==2.0.0a5)
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\flopa\appdata\roaming\python\python311\site-packages (from matplotlib->stable-baselines3==2.0.0a5) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\flopa\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3==2.0.0a5) (1.16.0)
# Collecting pytz>=2020.1 (from pandas->stable-baselines3==2.0.0a5)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->stable-baselines3==2.0.0a5)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\flopa\miniconda3\envs\tar\lib\site-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\flopa\miniconda3\envs\tar\lib\site-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\flopa\miniconda3\envs\tar\lib\site-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\flopa\miniconda3\envs\tar\lib\site-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (2025.4.26)
# Using cached stable_baselines3-2.0.0a5-py3-none-any.whl (177 kB)
# Using cached gymnasium-0.28.1-py3-none-any.whl (925 kB)
# Using cached huggingface_sb3-3.0-py3-none-any.whl (9.7 kB)
# Using cached huggingface_hub-0.33.0-py3-none-any.whl (514 kB)
# Using cached swig-4.3.1-py3-none-win_amd64.whl (2.6 MB)
# Using cached fsspec-2025.5.1-py3-none-any.whl (199 kB)
# Using cached jax_jumpy-1.0.0-py3-none-any.whl (20 kB)
# Using cached torch-2.7.1-cp311-cp311-win_amd64.whl (216.1 MB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached filelock-3.18.0-py3-none-any.whl (16 kB)
# Using cached matplotlib-3.10.3-cp311-cp311-win_amd64.whl (8.1 MB)
# Using cached contourpy-1.3.2-cp311-cp311-win_amd64.whl (222 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.58.2-cp311-cp311-win_amd64.whl (2.2 MB)
# Using cached kiwisolver-1.4.8-cp311-cp311-win_amd64.whl (71 kB)
# Using cached pillow-11.2.1-cp311-cp311-win_amd64.whl (2.7 MB)
# Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Using cached networkx-3.5-py3-none-any.whl (2.0 MB)
# Using cached pandas-2.3.0-cp311-cp311-win_amd64.whl (11.1 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Using cached wasabi-1.1.3-py3-none-any.whl (27 kB)
# Installing collected packages: swig, pytz, mpmath, wasabi, tzdata, tqdm, sympy, pyparsing, pillow, networkx, kiwisolver, jax-jumpy, fsspec, fonttools, filelock, cycler, contourpy, torch, pandas, matplotlib, huggingface-hub, gymnasium, stable-baselines3, huggingface_sb3
#
#    ----------------------------------------  0/24 [swig]
#    ----------------------------------------  0/24 [swig]
#    ----------------------------------------  0/24 [swig]
#    ----------------------------------------  0/24 [swig]
#    ----------------------------------------  0/24 [swig]
#    ----------------------------------------  0/24 [swig]
#    ----------------------------------------  0/24 [swig]
#    ----------------------------------------  0/24 [swig]
#    ----------------------------------------  0/24 [swig]
#    ----------------------------------------  0/24 [swig]
#    ----------------------------------------  0/24 [swig]
#    ----------------------------------------  0/24 [swig]
#    ----------------------------------------  0/24 [swig]
#    - --------------------------------------  1/24 [pytz]
#    - --------------------------------------  1/24 [pytz]
#    - --------------------------------------  1/24 [pytz]
#    - --------------------------------------  1/24 [pytz]
#    - --------------------------------------  1/24 [pytz]
#    - --------------------------------------  1/24 [pytz]
#    - --------------------------------------  1/24 [pytz]
#    - --------------------------------------  1/24 [pytz]
#    - --------------------------------------  1/24 [pytz]
#    - --------------------------------------  1/24 [pytz]
#    --- ------------------------------------  2/24 [mpmath]
#    --- ------------------------------------  2/24 [mpmath]
#    --- ------------------------------------  2/24 [mpmath]
#    --- ------------------------------------  2/24 [mpmath]
#    --- ------------------------------------  2/24 [mpmath]
#    --- ------------------------------------  2/24 [mpmath]
#    --- ------------------------------------  2/24 [mpmath]
#    --- ------------------------------------  2/24 [mpmath]
#    --- ------------------------------------  2/24 [mpmath]
#    --- ------------------------------------  2/24 [mpmath]
#    --- ------------------------------------  2/24 [mpmath]
#    --- ------------------------------------  2/24 [mpmath]
#    ----- ----------------------------------  3/24 [wasabi]
#    ------ ---------------------------------  4/24 [tzdata]
#    ------ ---------------------------------  4/24 [tzdata]
#    ------ ---------------------------------  4/24 [tzdata]
#    ------ ---------------------------------  4/24 [tzdata]
#    ------ ---------------------------------  4/24 [tzdata]
#    ------ ---------------------------------  4/24 [tzdata]
#    ------ ---------------------------------  4/24 [tzdata]
#    ------ ---------------------------------  4/24 [tzdata]
#    -------- -------------------------------  5/24 [tqdm]
#    -------- -------------------------------  5/24 [tqdm]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ---------- -----------------------------  6/24 [sympy]
#    ----------- ----------------------------  7/24 [pyparsing]
#    ------------- --------------------------  8/24 [pillow]
#    ------------- --------------------------  8/24 [pillow]
#    ------------- --------------------------  8/24 [pillow]
#    ------------- --------------------------  8/24 [pillow]
#    ------------- --------------------------  8/24 [pillow]
#    ------------- --------------------------  8/24 [pillow]
#    ------------- --------------------------  8/24 [pillow]
#    ------------- --------------------------  8/24 [pillow]
#    ------------- --------------------------  8/24 [pillow]
#    ------------- --------------------------  8/24 [pillow]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    --------------- ------------------------  9/24 [networkx]
#    ------------------ --------------------- 11/24 [jax-jumpy]
#    -------------------- ------------------- 12/24 [fsspec]
#    -------------------- ------------------- 12/24 [fsspec]
#    -------------------- ------------------- 12/24 [fsspec]
#    -------------------- ------------------- 12/24 [fsspec]
#    -------------------- ------------------- 12/24 [fsspec]
#    -------------------- ------------------- 12/24 [fsspec]
#    --------------------- ------------------ 13/24 [fonttools]
#    --------------------- ------------------ 13/24 [fonttools]
#    --------------------- ------------------ 13/24 [fonttools]
#    --------------------- ------------------ 13/24 [fonttools]
#    --------------------- ------------------ 13/24 [fonttools]
#    --------------------- ------------------ 13/24 [fonttools]
#    --------------------- ------------------ 13/24 [fonttools]
#    --------------------- ------------------ 13/24 [fonttools]
#    --------------------- ------------------ 13/24 [fonttools]
#    --------------------- ------------------ 13/24 [fonttools]
#    --------------------- ------------------ 13/24 [fonttools]
#    --------------------- ------------------ 13/24 [fonttools]
#    --------------------- ------------------ 13/24 [fonttools]
#    --------------------- ------------------ 13/24 [fonttools]
#    --------------------- ------------------ 13/24 [fonttools]
#    --------------------- ------------------ 13/24 [fonttools]
#    --------------------- ------------------ 13/24 [fonttools]
#    --------------------- ------------------ 13/24 [fonttools]
#    --------------------- ------------------ 13/24 [fonttools]
#    --------------------- ------------------ 13/24 [fonttools]
#    --------------------- ------------------ 13/24 [fonttools]
#    --------------------- ------------------ 13/24 [fonttools]
#    --------------------- ------------------ 13/24 [fonttools]
#    --------------------- ------------------ 13/24 [fonttools]
#    --------------------- ------------------ 13/24 [fonttools]
#    --------------------- ------------------ 13/24 [fonttools]
#    --------------------- ------------------ 13/24 [fonttools]
#    --------------------- ------------------ 13/24 [fonttools]
#    --------------------- ------------------ 13/24 [fonttools]
#    --------------------- ------------------ 13/24 [fonttools]
#    --------------------- ------------------ 13/24 [fonttools]
#    --------------------- ------------------ 13/24 [fonttools]
#    --------------------- ------------------ 13/24 [fonttools]
#    ----------------------- ---------------- 14/24 [filelock]
#    -------------------------- ------------- 16/24 [contourpy]
#    -------------------------- ------------- 16/24 [contourpy]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
# ...
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ---------------------------- ----------- 17/24 [torch]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------ --------- 18/24 [pandas]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    ------------------------------- -------- 19/24 [matplotlib]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    --------------------------------- ------ 20/24 [huggingface-hub]
#   Attempting uninstall: gymnasium
#    --------------------------------- ------ 20/24 [huggingface-hub]
#    ----------------------------------- ---- 21/24 [gymnasium]
#     Found existing installation: gymnasium 1.1.1
#    ----------------------------------- ---- 21/24 [gymnasium]
#    ----------------------------------- ---- 21/24 [gymnasium]
#     Uninstalling gymnasium-1.1.1:
#    ----------------------------------- ---- 21/24 [gymnasium]
#       Successfully uninstalled gymnasium-1.1.1
#    ----------------------------------- ---- 21/24 [gymnasium]
#    ----------------------------------- ---- 21/24 [gymnasium]
#    ----------------------------------- ---- 21/24 [gymnasium]
#    ----------------------------------- ---- 21/24 [gymnasium]
#    ----------------------------------- ---- 21/24 [gymnasium]
#    ----------------------------------- ---- 21/24 [gymnasium]
#    ----------------------------------- ---- 21/24 [gymnasium]
#    ----------------------------------- ---- 21/24 [gymnasium]
#    ----------------------------------- ---- 21/24 [gymnasium]
#    ----------------------------------- ---- 21/24 [gymnasium]
#    ----------------------------------- ---- 21/24 [gymnasium]
#    ----------------------------------- ---- 21/24 [gymnasium]
#    ----------------------------------- ---- 21/24 [gymnasium]
#    ----------------------------------- ---- 21/24 [gymnasium]
#    ----------------------------------- ---- 21/24 [gymnasium]
#    ----------------------------------- ---- 21/24 [gymnasium]
#    ----------------------------------- ---- 21/24 [gymnasium]
#    ------------------------------------ --- 22/24 [stable-baselines3]
#    ------------------------------------ --- 22/24 [stable-baselines3]
#    ------------------------------------ --- 22/24 [stable-baselines3]
#    ------------------------------------ --- 22/24 [stable-baselines3]
#    ------------------------------------ --- 22/24 [stable-baselines3]
#    -------------------------------------- - 23/24 [huggingface_sb3]
#    ---------------------------------------- 24/24 [huggingface_sb3]
#
# Successfully installed contourpy-1.3.2 cycler-0.12.1 filelock-3.18.0 fonttools-4.58.2 fsspec-2025.5.1 gymnasium-0.28.1 huggingface-hub-0.33.0 huggingface_sb3-3.0 jax-jumpy-1.0.0 kiwisolver-1.4.8 matplotlib-3.10.3 mpmath-1.3.0 networkx-3.5 pandas-2.3.0 pillow-11.2.1 pyparsing-3.2.3 pytz-2025.2 stable-baselines3-2.0.0a5 swig-4.3.1 sympy-1.14.0 torch-2.7.1 tqdm-4.67.1 tzdata-2025.2 wasabi-1.1.3

# %%
import importlib
import sys

# Paquetes a verificar con sus nombres de importación
required_packages = {
    "gymnasium": "gymnasium",
    "Box2D": "Box2D",
    "pygame": "pygame",
    "stable_baselines3": "stable_baselines3",
    "huggingface_sb3": "huggingface_sb3",
    "swig": "swig"
}

print("🔎 Verificando dependencias:\n")

for name, module in required_packages.items():
    try:
        mod = importlib.import_module(module)
        version = getattr(mod, "__version__", "✅ (versión no disponible)")
        print(f"{name:20} ➜ ✅ Encontrado, versión: {version}")
    except ModuleNotFoundError:
        print(f"{name:20} ➜ ❌ No encontrado")
    except Exception as e:
        print(f"{name:20} ➜ ⚠️ Error: {e}")

print("\n✅ Verificación completa.")
# Out:
# 🔎 Verificando dependencias:
#
# gymnasium            ➜ ✅ Encontrado, versión: 1.1.1
# Box2D                ➜ ✅ Encontrado, versión: 2.3.10
# pygame               ➜ ✅ Encontrado, versión: 2.6.1
# stable_baselines3    ➜ ✅ Encontrado, versión: 2.0.0a5
# huggingface_sb3      ➜ ✅ Encontrado, versión: ✅ (versión no disponible)
# swig                 ➜ ✅ Encontrado, versión: 4.3.1
#
# ✅ Verificación completa.

# %%
# !pip install ipywidgets

# %%
import gymnasium as gym
env = gym.make("LunarLander-v3", render_mode="rgb_array")
obs, info = env.reset()
print("Ambiente cargado 🎯")
# Out:
# Ambiente cargado 🎯

# %%
# !apt install swig cmake
# !pip install -r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt

# %%
# !python --version
# Out:
# Python 3.11.13

# %% [markdown]
# #### IMPORTS

# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# %% [markdown]
# ## Ejercicio 1. Frozen lake
#
# En este ejercicio nos enfrentamos al problema de [Frozen Lake](https://gymnasium.farama.org/environments/toy_text/frozen_lake/), donde el agente aprenderá a navegar desde el **estado inicial (S)** hasta una **meta (G)**, evadiendo los **agujeros (H)** y caminando solamente sobre los bloques de **hielo (F)**.
#
# Podemos tener dos tamaños de entorno:
# - map_name="4x4": una versión de cuadrícula 4x4
# - map_name="8x8": una versión de cuadrícula 8x8
#
#
# El entorno tiene dos modos:
# - is_slippery=False: El agente siempre se mueve en la dirección deseada  (determinístico).
# - is_slippery=True: El agente puede no moverse siempre en la dirección deseada debido al hielo resbaladizo (estocástico).
#
# Trabajaremos con la versión 8x8, y determinística.
#
# ### Implementaremos un agente basado en Q-learning
# ¿Que tipo de metodo es este?

# %% [markdown]
# ##### RESPUESTA -->

# %% [markdown]
# #### 1.1 Definir el ambiente.

# %%
#TODO Definir el ambiente `FrozenLake-v1` y renderizarlo en modo rgb_array
#env =

# Reiniciar el entorno y renderizar la imagen inicial
env.reset()
image = env.render()

# Mostrar la imagen del entorno con matplotlib
plt.imshow(image)
plt.axis('off')
plt.show()

#TODO Imprimir la cantidad de posibles estados y la cantidad de acciones posibles
state_space = #....
print("Hay ", state_space, " estados posibles")

action_space = #....
print("Hay ", action_space, " acciones posibles")

# %% [markdown]
# Cada uno de los estados es representado por un entero, de izquierda a derecha y de arriba a abajo. El estado inicial es $S = **$ y el estado final $G = **$.
#
# El espacio de acciones es discreto, con 4 acciones disponibles:
# - 0: ...
# - 1: ...
# - 2: ...
# - 3: ...
#
# Función de recompensa:
# - ...

# %% [markdown]
# ### Definición de las políticas de decisión
#
# Como Q-learning es un algoritmo off-policy, se utiliza una política de decisión para actuar y otra diferente para actualizar la tabla Q.
# Se utilizarán:
# - Política greedy (política de actualización)
# - Política epsilon-greedy (política de actuación)
#
# #### 1.2 Crear una función que implemente la política greedy. Las entradas son la tabla Q y el estado actual, y la salida es la acción a tomar.

# %%
#TODO crear una funcion que implemente la politica greedy.

# %% [markdown]
# #### 1.3 Crear otra función que implemente la política epsilon-greedy.
# Además de los parámetros de entrada de la función anterior, agregar $ϵ$, que es la variable que controla la relación exploración/explotación a la hora de decidir que acción tomar.

# %%
#TODO crear una funcion que implemente la politica epsilon greedy.

# %% [markdown]
# Una vez creadas las funciones anteriores, solamente falta crear la función de entrenamiento. La misma debe seguir el siguiente pseudo-código:
#
# ```
# Para cada episodio en el total de episodios de entrenamiento:
#
# Reducir epsilon (ya que necesitamos cada vez menos exploración)
# Reiniciar el entorno
#
#   Para cada paso en el máximo número de timesteps:
#     Elegir la acción At utilizando la política epsilon-greedy
#     Realizar la acción (a) y observar el nuevo estado (s') y la recompensa (r)
#     Actualizar el valor de Q(s,a) usando la ecuación de Bellman
#     Si el episodio ha terminado, finalizarlo
#
# ```
#
# **Actualización de la Tabla Q**
#
# La función de valor Q se actualiza utilizando la ecuación de Bellman:
#
# $$ Q(s, a) \leftarrow Q(s, a) + \alpha \left[ R + \gamma \max_{a'} Q(s', a') - Q(s, a) \right] $$
#
# donde:
# - $ \alpha $ es la tasa de aprendizaje.
# - $ \gamma $ es el factor de descuento.
# - $ R $ es la recompensa recibida.
# - $ s' $ es el nuevo estado.
# - $ a' $ es la acción que maximiza el valor Q en el nuevo estado.
#
# **Observación**: Es importante que la variable `epsilon` varie entre un valor máximo y mínimo, y que vaya decayendo de manera exponencial según el `decay_rate` y el número de episodio en el que se esté.
#
# **Observación 2**: Almacenar la ganacia acumulada para cada episodio para poder graficar la evolución de entrenamiento
#
# #### 1.4 Crear la función de entrenamiento

# %%
def train(n_training_episodes, min_epsilon, max_epsilon, decay_rate, env, max_steps, gamma, learning_rate, Qtable):
  rewards = []
  #....
  return Qtable, rewards

# %% [markdown]
# #### 1.5 Definir los hiperparámetros, inicializar la tabla Q llena de ceros y entrenar el agente

# %%
# Parámetros de entrenamiento
n_training_episodes = #....  # Total de episodios de entrenamiento
learning_rate = #....          # Tasa de aprendizaje

# Parámetros del entorno
max_steps = #....              # Máximo de pasos por episodio
gamma = #....                 # Tasa de descuento

# Parámetros de exploración
max_epsilon = #....           # Probabilidad de exploración al inicio
min_epsilon = #....           # Probabilidad mínima de exploración
decay_rate = #....          # Tasa de decaimiento de epsilon

# inicializar la tabla Q con ceros
Qtable_frozenlake = #....

# %%
Qtable_frozenlake, rewards = train(n_training_episodes, min_epsilon, max_epsilon, decay_rate, env, max_steps, gamma, learning_rate, Qtable_frozenlake)

# %% [markdown]
# #### 1.6 El siguente código grafica el promedio de recompensas por cada bloque de 1000 episodios. Observar y explicar su comportamiento.

# %%
# Calculamos el promedio de recompensas por cada bloque de 1000 episodios
reward_per_thousand_episodes = np.split(np.array(rewards), n_training_episodes/1000)
count = 1000
avg_rewards = []

for r in reward_per_thousand_episodes:
    avg_rewards.append(sum(r/1000))
    count += 1000

# Visualizamos el promedio de recompensas
plt.plot(avg_rewards)
plt.xlabel('Bloques de 1000 episodios')
plt.ylabel('Promedio de Recompensas')
plt.title('Promedio de Recompensas por Episodio durante el Entrenamiento')
plt.grid()
plt.show()

# %% [markdown]
# #### 1.7 Simular un juego y obtener la ganancia (reward) total acumulada. Ver si el agente logró llegar a la meta (si el roward total es positivo).
#
# En caso contrario variar los hiperparámetros.

# %%
total_reward = 0

# Jugar una vez con la tabla Q entrenada y obtener la ganancia acumulada
#....

if total_reward > 0:
  print('Llgegaste a la meta!')
print('total_reward ', total_reward)

# %% [markdown]
# #### 1.8 Qué impacto tiene en la solución obtenida los diferentes hiperparámetros? Qué sucede al variar el `decay_rate` y `max_epsilon` y `min_epsilon`?

# %% [markdown]
# ##### RESPUESTA -->

# %% [markdown]
# #### 1.9 Si se quisiera un agente que tome el camino más corto, ¿qué solución/es se le ocurre? Implementarla/s

# %% [markdown]
# ##### RESPUESTA -->

# %% [markdown]
# La siguente función toma la tabla Q entrenada y simula un juego, guardando los frames y generando un video.

# %%
from matplotlib import animation
def generate_frames(q_table, env, max_steps=100):
    """Genera una lista de frames para crear la animación"""
    state, _ = env.reset()
    frames = [env.render()]  # Render del estado inicial
    for step in range(max_steps):
        action = greedy_policy(q_table, state)
        next_state, reward, done, _, _ = env.step(action)
        frames.append(env.render())  # Guardar el nuevo estado como frame

        state = next_state

        if done:
            break
    return frames

def save_video(frames, filename='q_learning_frozenlake.mp4'):
    """Guardar el video de los frames en un archivo .mp4"""
    fig = plt.figure()
    patch = plt.imshow(frames[0])
    plt.axis('off')

    def animate(i):
        patch.set_data(frames[i])

    anim = animation.FuncAnimation(fig, animate, frames=len(frames), interval=300)

    # Guardar animación
    anim.save(filename, writer='ffmpeg', fps=5)
    plt.close()

# %%
# Generar los frames a partir de la tabla Q
frames = generate_frames(Qtable_frozenlake, env)

# Guardar el video
save_video(frames)

# %% [markdown]
# ## Ejercicio 2. Ta-te-ti usando Q-learning
#
# En esta sección, vamos a entrenar un agente de aprendizaje por refuerzo utilizando el algoritmo de **Q-Learning** para jugar al juego de **Ta-Te-Ti**. El objetivo es que el agente aprenda a tomar decisiones óptimas en cada estado del juego para maximizar su recompensa y ganar la mayor cantidad de partidas posible.
#
# En el archivo ta-te-ti_env.py se define el entorno del **Ta-Te-Ti** que utilizaremos para entrenar nuestro agente de Q-Learning. Buscamos crear un entorno compatible con las interfaces de Gym, lo que significa que debe incluir métodos como `reset`, `render`, `step`, así como propiedades como `observation_space` y `action_space`. Es importante leer y entender la definición del ambiente antes de continuar.
#
# El entorno de **Ta-Te-Ti** consta de un tablero de $3\times3$, para el cual se utiliza un vector de $9$ valores para definir su estado. Este vector se rellena con valores $0$ para los lugares disponibles, con $1$ para  indicar las posiciones donde juega el agente y con $-1$ para indicar las posiciones del oponente.
# El environment permite recibir como parámetros de inicialización los reward para el caso donde el agente gana, pierde o empata.

# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt

from ta_te_ti_env import TaTeTiEnv, play_against_agent

env = TaTeTiEnv()

# %% [markdown]
# #### 2.1. Observar la cantidad de posibles estados y posibles acciones a tomar.

# %%
# state_space = #....
# print("Hay ", state_space, " estados posibles")

# action_space = #....
# print("Hay ", action_space, " acciones posibles")

# %% [markdown]
# #### 2.2. Definir los hiperparámetros y entrenar el agente utilizando las mismas funciones creadas para la parte 2. Variar los diferentes hiperparámetros y diferentes rewards para mejorar la tabla Q obtenida.

# %%
win_reward = #....
draw_reward = #....
loss_reward = #....
env = TaTeTiEnv(win_reward, draw_reward, loss_reward) # Se define el entorno

# Parámetros de entrenamiento
n_training_episodes = #....  # Total de episodios de entrenamiento
learning_rate = 0.7          # Tasa de aprendizaje

# Parámetros del entorno
max_steps = 9               # Máximo de pasos por episodio
gamma = #....                # Tasa de descuento
eval_seed = []               # La semilla de evaluación del entorno

# Parámetros de exploración
max_epsilon = #....            # Probabilidad de exploración al inicio
min_epsilon = #....           # Probabilidad mínima de exploración
decay_rate = #....         # Tasa de decaimiento de epsilon

Qtable = np.zeros((env.observation_space.n, env.action_space.n)) # Inicializamos la tabla Q
Qtable, rewards = train(n_training_episodes, min_epsilon, max_epsilon, decay_rate, env, max_steps, learning_rate, gamma, Qtable) # Entrenamos el agente

# %% [markdown]
# Se observa a continuación la evolución de la recompensa a medida que se avanza el entrenamiento

# %%
# Calculamos el promedio de recompensas por cada bloque de 1000 episodios
reward_per_thousand_episodes = np.split(np.array(rewards), n_training_episodes/1000)
count = 1000
avg_rewards = []

for r in reward_per_thousand_episodes:
    avg_rewards.append(sum(r/1000))
    count += 1000

# Visualizamos el promedio de recompensas
plt.plot(avg_rewards)
plt.xlabel('Bloques de 1000 episodios')
plt.ylabel('Promedio de Recompensas')
plt.title('Promedio de Recompensas por Episodio durante el Entrenamiento')
plt.grid()
plt.show()

# %% [markdown]
# #### 2.3 Jugar contra el agente, y observar donde y cuando falla. Ajustar hiperparámetros y rewards para mejorar su rendimiento
#
# En particular, experimentar con distintos valores de recompensa. Es interesante visualizar que pasa para los casos donde la recompensa negativa (cuando el agente pierde) es más fuerte que para cuando gana.

# %%
play_against_agent(Qtable, env)
