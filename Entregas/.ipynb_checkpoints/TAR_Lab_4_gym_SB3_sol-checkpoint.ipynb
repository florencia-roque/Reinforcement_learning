# %% [markdown]
# # TAR: Taller de Aprendizaje por Refuerzo 2025
# ## Laboratorio 5: Gymnasium + stable_baselines3
#
# ### Stable Baselines3 (SB3) es una libreria algoritmos de reinforcement learning implementada en PyTorch.

# %% [markdown]
# *Ejecutar esta celda solo la primera vez (si estan usando un entorno local - es la misma del lab 4) para descargar e instalar los paquetes necesarios. Si ejecutan el notebook en colab tendran que ejecutarla cada vez que reinicien el kernel*

# %%
# !apt install swig cmake
# !pip install -r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt

# %% [markdown]
# #### IMPORTS

# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# %% [markdown]
# ## Ejercicio 1. Lunar Landing
#
# En este ejemplo entrenaremos un agente que aprenda a aterrizar correctamente una nave en la luna.
# Doc del ambiente: https://gymnasium.farama.org/environments/box2d/lunar_lander/

# %% [markdown]
# #### 1.1 Estudiar el ambiente

# %%
#TODO Definir el ambiente `LunarLander-v2` e imprimir el tamaño del espacio de observación y del espacio de acciones.

env = gym.make("LunarLander-v2", render_mode="human")
env.reset()

tamaño_obs = env.observation_space.shape  # Tamaño del espacio de observación
print("Tamaño del espacio de observación: ", tamaño_obs)

tamaño_acciones = env.action_space.n # ....
print("Tamaño del espacio de acción: ", tamaño_acciones)

# %% [markdown]
# El vector de **observación** corresponde a:
#
# - x coordinate
# - y coordinate
# - vx
# - vy
# - angle
# - w
# - left leg on the ground or not
# - right leg on the ground or not
#
# Por otro lado, el espacio de **acciones** es:
#
# - Acción 0: do nothing
# - Acción 1: fire left orientation engine
# - Acción 2: fire main engine
# - Acción 3: fire right orientation engine
#
# Función de **recompensa**:
#
#   Después de cada paso, se otorga una recompensa. La recompensa total de un episodio es la suma de las recompensas de todos los pasos dentro de ese episodio.
#
#   Para cada paso, la recompensa:
#
# - es positiva si se acerca al lugar de aterrizaje y negativa si se aleja
# - es positiva si la velocidad aumenta y negativa si disminuye
# - es 10 para cada pata que este tocando el suelo
# - es - 0.03 cada vez q usa un motor lateral
# - es -0.3 cada vez q usa el motor principal
# - 100 si aterriza correctamente
# - -100 si se choca contra el piso
#
# Un episodio termina si:
# - si choca contra la luna
# - si el lander se va de la pantalla
# - si el lander no se mueve

# %% [markdown]
# ##### Multi-procesamiento
# A continuación se vectoriza el ambiente para poder paralelizar el entrenamiento, (por suerte la libreria nos da las heramientas para lograr esto sin mucho esfuerzo)

# %%
from stable_baselines3.common.env_util import make_vec_env

# Create the environment
env = make_vec_env('LunarLander-v2', n_envs=16)

# %% [markdown]
# #### 1.2 Definir el modelo usando el modelo [Proximal Policy Optimization(PPO) de stable_baselines3](https://stable-baselines3.readthedocs.io/en/master/modules/ppo.html)
#
# Leer la documentación y variar diferentes hiperparámetros como `batch_size`, `gamma`, entre otros.
#
# ¿Que tipo de metodo implementa?

# %% [markdown]
# ##### RESPUESTA --> Policy based

# %%
from stable_baselines3 import PPO

model = PPO(
    policy = 'MlpPolicy',
    env = env,
    n_steps = 1024,
    batch_size = 64,
    n_epochs = 4,
    gamma = 0.999,
    gae_lambda = 0.98,
    ent_coef = 0.01,
    device="cpu",
    verbose=1)

# %%
# Entrenar por 1.000.000 timesteps

model.learn(total_timesteps=1000000)

model_name = "ppo-LunarLander-v2"

# Guardar el modelo
model.save(model_name)

# %% [markdown]
# #### 1.3 Evaluación del modelo:
#
# ¿Como podemos evaluar si el agente aprendió a aterrizar la nave?

# %% [markdown]
# ##### RESPUESTA --> Una recompensa de 200 es señal de un buen aterrizaje

# %%
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor

eval_env = Monitor(gym.make("LunarLander-v2", render_mode='rgb_array'))
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")

# %% [markdown]
# #### 1.4 Correr el agente entrenado y guardar un video del aterrizaje
#
# si esto da error de timeout pueden generar un .py y correrlo desde consola para guardar el video

# %%
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from gymnasium.wrappers import RecordVideo

# Load the trained model
model = PPO.load("ppo-LunarLander-v2")

# Create the environment with the proper render_mode for video recording
env = DummyVecEnv([lambda: RecordVideo(gym.make("LunarLander-v2", render_mode="rgb_array"), "./videos/PPO", episode_trigger=lambda x: True)])

# Reset the environment to get the initial observation
obs = env.reset()
done = False

# Play one episode to capture the video
while not done:
    action, _ = model.predict(obs)
    obs, reward, done, info = env.step(action)
    
# Close the environment to save the video file
env.close()

print("Video saved in the './videos' directory.")

# %% [markdown]
# ## Ejercicio 2. Cart Pole
#
# En este ejemplo entrenaremos un agente que aprenda a equilibrar un poste sobre un carrito que se mueve sobre una linea.
# Doc del ambiente: https://gymnasium.farama.org/environments/classic_control/cart_pole/

# %% [markdown]
# #### 2.1 Estudiar el ambiente:
#
# ¿Como son el espacio de acciones y el espacio de estados?

# %% [markdown]
# ##### RESPUESTA -->
# Acciones discretas, empujar a la derecha o izquierda cambia la velocidad del carro, pero depende del angulo de la barra el efecto de la accion.
#
# Espacio de estados continuos (acotados) 4 dimensiones:
# - posicion del carro
# - velocidad del carro
# - angulo de la barra
# - velocidad angular de la barra

# %%
#TODO Definir el ambiente e imprimir el tamaño del espacio de observación y del espacio de acciones.
env= gym.make("CartPole-v1", render_mode="rgb_array")

env.reset()

tamaño_obs = env.observation_space.shape  # Tamaño del espacio de observación
print("Tamaño del espacio de observación: ", tamaño_obs)

tamaño_acciones = env.action_space.n # ....
print("Tamaño del espacio de acción: ", tamaño_acciones)
# Out:
# Tamaño del espacio de observación:  (4,)
# Tamaño del espacio de acción:  2

# %% [markdown]
# #### 2.2 Definir el modelo usando el modelo - A2C de stable_baselines3
#
# ¿Que tipo de metodo implementa?

# %% [markdown]
# ##### RESPUESTA --> Policy base, pero puede decirse que es combinado, porque aprende tmb una funcion de valor

# %%
from stable_baselines3 import A2C

model = A2C(
    policy = 'MlpPolicy',
    env = env,
    n_steps = 5,
    gamma = 0.99,
    gae_lambda = 0.95,
    ent_coef = 0.01,
    device="cpu",
    verbose=1)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# #### 2.3 Vectorizar el ambiente y entrenar el modelo

# %%
#TODO vectorizar el ambiente y entrenar el agente A2C
from stable_baselines3.common.env_util import make_vec_env

# Create the environment
env = make_vec_env('CartPole-v1', n_envs=16)

model = A2C(
    policy = 'MlpPolicy',
    env = env,
    n_steps = 5,
    gamma = 0.99,
    gae_lambda = 0.95,
    ent_coef = 0.01,
    device="cpu",
    verbose=1)


model.learn(total_timesteps=1000000)

model_name = "A2C-CartPole-v1"

# Guardar el modelo
model.save(model_name)
# Out:
# Using cpu device
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 30.8       |
# |    ep_rew_mean        | 30.8       |
# | time/                 |            |
# |    fps                | 1162       |
# |    iterations         | 100        |
# |    time_elapsed       | 6          |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -0.584     |
# |    explained_variance | 0.38004923 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 99         |
# |    policy_loss        | 0.452      |
# |    value_loss         | 14.7       |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 76.9       |
# |    ep_rew_mean        | 76.9       |
# | time/                 |            |
# |    fps                | 1927       |
# |    iterations         | 200        |
# |    time_elapsed       | 8          |
# |    total_timesteps    | 16000      |
# | train/                |            |
# |    entropy_loss       | -0.59      |
# |    explained_variance | 0.19758737 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 199        |
# |    policy_loss        | 0.683      |
# |    value_loss         | 16.7       |
# --------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 151         |
# |    ep_rew_mean        | 151         |
# | time/                 |             |
# |    fps                | 2507        |
# |    iterations         | 300         |
# |    time_elapsed       | 9           |
# |    total_timesteps    | 24000       |
# | train/                |             |
# |    entropy_loss       | -0.541      |
# |    explained_variance | 0.035382032 |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 299         |
# |    policy_loss        | 1.11        |
# |    value_loss         | 4.66        |
# ---------------------------------------
# ----------------------------------------
# | rollout/              |              |
# |    ep_len_mean        | 188          |
# |    ep_rew_mean        | 188          |
# | time/                 |              |
# |    fps                | 2999         |
# |    iterations         | 400          |
# |    time_elapsed       | 10           |
# |    total_timesteps    | 32000        |
# | train/                |              |
# |    entropy_loss       | -0.539       |
# |    explained_variance | 0.0018835068 |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 399          |
# |    policy_loss        | 0.821        |
# |    value_loss         | 26.7         |
# ----------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 182       |
# |    ep_rew_mean        | 182       |
# | time/                 |           |
# |    fps                | 3343      |
# |    iterations         | 500       |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 40000     |
# | train/                |           |
# |    entropy_loss       | -0.544    |
# |    explained_variance | 0.4047318 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | -0.833    |
# |    value_loss         | 60.4      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 182       |
# |    ep_rew_mean        | 182       |
# | time/                 |           |
# |    fps                | 3623      |
# |    iterations         | 600       |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 48000     |
# | train/                |           |
# |    entropy_loss       | -0.513    |
# |    explained_variance | 0.9897305 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | 0.627     |
# |    value_loss         | 2.53      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 129       |
# |    ep_rew_mean        | 129       |
# | time/                 |           |
# |    fps                | 3863      |
# |    iterations         | 700       |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 56000     |
# | train/                |           |
# |    entropy_loss       | -0.472    |
# |    explained_variance | 0.9825323 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | 0.373     |
# |    value_loss         | 2.82      |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 63         |
# |    ep_rew_mean        | 63         |
# | time/                 |            |
# |    fps                | 4092       |
# |    iterations         | 800        |
# |    time_elapsed       | 15         |
# |    total_timesteps    | 64000      |
# | train/                |            |
# |    entropy_loss       | -0.495     |
# |    explained_variance | 0.98005575 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | 0.161      |
# |    value_loss         | 4.68       |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 78.6       |
# |    ep_rew_mean        | 78.6       |
# | time/                 |            |
# |    fps                | 4235       |
# |    iterations         | 900        |
# |    time_elapsed       | 16         |
# |    total_timesteps    | 72000      |
# | train/                |            |
# |    entropy_loss       | -0.509     |
# |    explained_variance | 0.99568284 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | 0.741      |
# |    value_loss         | 4.42       |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 124       |
# |    ep_rew_mean        | 124       |
# | time/                 |           |
# |    fps                | 4379      |
# |    iterations         | 1000      |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 80000     |
# | train/                |           |
# |    entropy_loss       | -0.501    |
# |    explained_variance | 0.9629599 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | 0.728     |
# |    value_loss         | 2.27      |
# -------------------------------------
# ----------------------------------------
# | rollout/              |              |
# |    ep_len_mean        | 178          |
# |    ep_rew_mean        | 178          |
# | time/                 |              |
# |    fps                | 4416         |
# |    iterations         | 1100         |
# |    time_elapsed       | 19           |
# |    total_timesteps    | 88000        |
# | train/                |              |
# |    entropy_loss       | -0.545       |
# |    explained_variance | -0.010599494 |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1099         |
# |    policy_loss        | 0.506        |
# |    value_loss         | 1.83         |
# ----------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 261       |
# |    ep_rew_mean        | 261       |
# | time/                 |           |
# |    fps                | 4475      |
# |    iterations         | 1200      |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 96000     |
# | train/                |           |
# |    entropy_loss       | -0.426    |
# |    explained_variance | 0.9942038 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | 0.224     |
# |    value_loss         | 3.25      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 90        |
# |    ep_rew_mean        | 90        |
# | time/                 |           |
# |    fps                | 4555      |
# |    iterations         | 1300      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 104000    |
# | train/                |           |
# |    entropy_loss       | -0.487    |
# |    explained_variance | 0.9927535 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | 0.176     |
# |    value_loss         | 4.43      |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 109        |
# |    ep_rew_mean        | 109        |
# | time/                 |            |
# |    fps                | 4644       |
# |    iterations         | 1400       |
# |    time_elapsed       | 24         |
# |    total_timesteps    | 112000     |
# | train/                |            |
# |    entropy_loss       | -0.53      |
# |    explained_variance | 0.20184577 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1399       |
# |    policy_loss        | 0.475      |
# |    value_loss         | 1.39       |
# --------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 193         |
# |    ep_rew_mean        | 193         |
# | time/                 |             |
# |    fps                | 4745        |
# |    iterations         | 1500        |
# |    time_elapsed       | 25          |
# |    total_timesteps    | 120000      |
# | train/                |             |
# |    entropy_loss       | -0.494      |
# |    explained_variance | 0.036898613 |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1499        |
# |    policy_loss        | 0.487       |
# |    value_loss         | 0.966       |
# ---------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 235        |
# |    ep_rew_mean        | 235        |
# | time/                 |            |
# |    fps                | 4833       |
# |    iterations         | 1600       |
# |    time_elapsed       | 26         |
# |    total_timesteps    | 128000     |
# | train/                |            |
# |    entropy_loss       | -0.479     |
# |    explained_variance | 0.99157995 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1599       |
# |    policy_loss        | 0.0152     |
# |    value_loss         | 4          |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 171       |
# |    ep_rew_mean        | 171       |
# | time/                 |           |
# |    fps                | 4945      |
# |    iterations         | 1700      |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 136000    |
# | train/                |           |
# |    entropy_loss       | -0.515    |
# |    explained_variance | 0.9949828 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | 0.429     |
# |    value_loss         | 0.939     |
# -------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 204         |
# |    ep_rew_mean        | 204         |
# | time/                 |             |
# |    fps                | 5054        |
# |    iterations         | 1800        |
# |    time_elapsed       | 28          |
# |    total_timesteps    | 144000      |
# | train/                |             |
# |    entropy_loss       | -0.519      |
# |    explained_variance | 0.052785337 |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1799        |
# |    policy_loss        | 0.319       |
# |    value_loss         | 0.513       |
# ---------------------------------------
# ----------------------------------------
# | rollout/              |              |
# |    ep_len_mean        | 255          |
# |    ep_rew_mean        | 255          |
# | time/                 |              |
# |    fps                | 5154         |
# |    iterations         | 1900         |
# |    time_elapsed       | 29           |
# |    total_timesteps    | 152000       |
# | train/                |              |
# |    entropy_loss       | -0.438       |
# |    explained_variance | -0.009149432 |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1899         |
# |    policy_loss        | 0.276        |
# |    value_loss         | 0.305        |
# ----------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 308         |
# |    ep_rew_mean        | 308         |
# | time/                 |             |
# |    fps                | 5245        |
# |    iterations         | 2000        |
# |    time_elapsed       | 30          |
# |    total_timesteps    | 160000      |
# | train/                |             |
# |    entropy_loss       | -0.46       |
# |    explained_variance | 0.017861187 |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1999        |
# |    policy_loss        | 0.201       |
# |    value_loss         | 0.166       |
# ---------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 364        |
# |    ep_rew_mean        | 364        |
# | time/                 |            |
# |    fps                | 5310       |
# |    iterations         | 2100       |
# |    time_elapsed       | 31         |
# |    total_timesteps    | 168000     |
# | train/                |            |
# |    entropy_loss       | -0.556     |
# |    explained_variance | 0.24505824 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2099       |
# |    policy_loss        | 0.138      |
# |    value_loss         | 0.0734     |
# --------------------------------------
# ------------------------------------------
# | rollout/              |                |
# |    ep_len_mean        | 417            |
# |    ep_rew_mean        | 417            |
# | time/                 |                |
# |    fps                | 5397           |
# |    iterations         | 2200           |
# |    time_elapsed       | 32             |
# |    total_timesteps    | 176000         |
# | train/                |                |
# |    entropy_loss       | -0.541         |
# |    explained_variance | -0.00027787685 |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 2199           |
# |    policy_loss        | -4.31          |
# |    value_loss         | 209            |
# ------------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 468        |
# |    ep_rew_mean        | 468        |
# | time/                 |            |
# |    fps                | 5480       |
# |    iterations         | 2300       |
# |    time_elapsed       | 33         |
# |    total_timesteps    | 184000     |
# | train/                |            |
# |    entropy_loss       | -0.482     |
# |    explained_variance | 0.39700395 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2299       |
# |    policy_loss        | 0.0173     |
# |    value_loss         | 0.000799   |
# --------------------------------------
# ----------------------------------------
# | rollout/              |              |
# |    ep_len_mean        | 430          |
# |    ep_rew_mean        | 430          |
# | time/                 |              |
# |    fps                | 5532         |
# |    iterations         | 2400         |
# |    time_elapsed       | 34           |
# |    total_timesteps    | 192000       |
# | train/                |              |
# |    entropy_loss       | -0.553       |
# |    explained_variance | 0.0003684759 |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2399         |
# |    policy_loss        | -0.207       |
# |    value_loss         | 228          |
# ----------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 416        |
# |    ep_rew_mean        | 416        |
# | time/                 |            |
# |    fps                | 5609       |
# |    iterations         | 2500       |
# |    time_elapsed       | 35         |
# |    total_timesteps    | 200000     |
# | train/                |            |
# |    entropy_loss       | -0.563     |
# |    explained_variance | 0.41033012 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2499       |
# |    policy_loss        | 0.00036    |
# |    value_loss         | 1.2e-05    |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 395       |
# |    ep_rew_mean        | 395       |
# | time/                 |           |
# |    fps                | 5682      |
# |    iterations         | 2600      |
# |    time_elapsed       | 36        |
# |    total_timesteps    | 208000    |
# | train/                |           |
# |    entropy_loss       | -0.607    |
# |    explained_variance | 0.7086041 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2599      |
# |    policy_loss        | 0.00377   |
# |    value_loss         | 0.000285  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 380      |
# |    ep_rew_mean        | 380      |
# | time/                 |          |
# |    fps                | 5742     |
# |    iterations         | 2700     |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 216000   |
# | train/                |          |
# |    entropy_loss       | -0.6     |
# |    explained_variance | 0.976216 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | 1.73e-05 |
# |    value_loss         | 0.00222  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 326       |
# |    ep_rew_mean        | 326       |
# | time/                 |           |
# |    fps                | 5819      |
# |    iterations         | 2800      |
# |    time_elapsed       | 38        |
# |    total_timesteps    | 224000    |
# | train/                |           |
# |    entropy_loss       | -0.603    |
# |    explained_variance | 0.9394485 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2799      |
# |    policy_loss        | 0.0011    |
# |    value_loss         | 0.000483  |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 355        |
# |    ep_rew_mean        | 355        |
# | time/                 |            |
# |    fps                | 5858       |
# |    iterations         | 2900       |
# |    time_elapsed       | 39         |
# |    total_timesteps    | 232000     |
# | train/                |            |
# |    entropy_loss       | -0.604     |
# |    explained_variance | 0.93148273 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2899       |
# |    policy_loss        | -0.00155   |
# |    value_loss         | 4.94e-05   |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 365        |
# |    ep_rew_mean        | 365        |
# | time/                 |            |
# |    fps                | 5885       |
# |    iterations         | 3000       |
# |    time_elapsed       | 40         |
# |    total_timesteps    | 240000     |
# | train/                |            |
# |    entropy_loss       | -0.614     |
# |    explained_variance | 0.82888496 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2999       |
# |    policy_loss        | -0.000935  |
# |    value_loss         | 5.07e-05   |
# --------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 375         |
# |    ep_rew_mean        | 375         |
# | time/                 |             |
# |    fps                | 5933        |
# |    iterations         | 3100        |
# |    time_elapsed       | 41          |
# |    total_timesteps    | 248000      |
# | train/                |             |
# |    entropy_loss       | -0.551      |
# |    explained_variance | -0.10767603 |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3099        |
# |    policy_loss        | 0.000793    |
# |    value_loss         | 0.000136    |
# ---------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 386        |
# |    ep_rew_mean        | 386        |
# | time/                 |            |
# |    fps                | 5982       |
# |    iterations         | 3200       |
# |    time_elapsed       | 42         |
# |    total_timesteps    | 256000     |
# | train/                |            |
# |    entropy_loss       | -0.551     |
# |    explained_variance | 0.56444764 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3199       |
# |    policy_loss        | 0.00112    |
# |    value_loss         | 0.000128   |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 423       |
# |    ep_rew_mean        | 423       |
# | time/                 |           |
# |    fps                | 6029      |
# |    iterations         | 3300      |
# |    time_elapsed       | 43        |
# |    total_timesteps    | 264000    |
# | train/                |           |
# |    entropy_loss       | -0.608    |
# |    explained_variance | 0.6667663 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3299      |
# |    policy_loss        | -0.000389 |
# |    value_loss         | 0.000145  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 472       |
# |    ep_rew_mean        | 472       |
# | time/                 |           |
# |    fps                | 6060      |
# |    iterations         | 3400      |
# |    time_elapsed       | 44        |
# |    total_timesteps    | 272000    |
# | train/                |           |
# |    entropy_loss       | -0.61     |
# |    explained_variance | 0.8699979 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3399      |
# |    policy_loss        | -0.00228  |
# |    value_loss         | 9.51e-05  |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 468        |
# |    ep_rew_mean        | 468        |
# | time/                 |            |
# |    fps                | 6085       |
# |    iterations         | 3500       |
# |    time_elapsed       | 46         |
# |    total_timesteps    | 280000     |
# | train/                |            |
# |    entropy_loss       | -0.573     |
# |    explained_variance | 0.76230574 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3499       |
# |    policy_loss        | -0.00897   |
# |    value_loss         | 0.000649   |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 459       |
# |    ep_rew_mean        | 459       |
# | time/                 |           |
# |    fps                | 6129      |
# |    iterations         | 3600      |
# |    time_elapsed       | 46        |
# |    total_timesteps    | 288000    |
# | train/                |           |
# |    entropy_loss       | -0.538    |
# |    explained_variance | 0.6933075 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3599      |
# |    policy_loss        | -0.00109  |
# |    value_loss         | 0.000124  |
# -------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 440         |
# |    ep_rew_mean        | 440         |
# | time/                 |             |
# |    fps                | 6147        |
# |    iterations         | 3700        |
# |    time_elapsed       | 48          |
# |    total_timesteps    | 296000      |
# | train/                |             |
# |    entropy_loss       | -0.574      |
# |    explained_variance | -0.34575808 |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3699        |
# |    policy_loss        | 0.000997    |
# |    value_loss         | 7.62e-05    |
# ---------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 423        |
# |    ep_rew_mean        | 423        |
# | time/                 |            |
# |    fps                | 6165       |
# |    iterations         | 3800       |
# |    time_elapsed       | 49         |
# |    total_timesteps    | 304000     |
# | train/                |            |
# |    entropy_loss       | -0.574     |
# |    explained_variance | 0.38856018 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3799       |
# |    policy_loss        | 0.00305    |
# |    value_loss         | 0.000284   |
# --------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 415      |
# |    ep_rew_mean        | 415      |
# | time/                 |          |
# |    fps                | 6200     |
# |    iterations         | 3900     |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 312000   |
# | train/                |          |
# |    entropy_loss       | -0.571   |
# |    explained_variance | 0.814901 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | -0.00319 |
# |    value_loss         | 0.000218 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 416       |
# |    ep_rew_mean        | 416       |
# | time/                 |           |
# |    fps                | 6231      |
# |    iterations         | 4000      |
# |    time_elapsed       | 51        |
# |    total_timesteps    | 320000    |
# | train/                |           |
# |    entropy_loss       | -0.609    |
# |    explained_variance | 0.3345939 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3999      |
# |    policy_loss        | -0.000924 |
# |    value_loss         | 1.55e-05  |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 421        |
# |    ep_rew_mean        | 421        |
# | time/                 |            |
# |    fps                | 6244       |
# |    iterations         | 4100       |
# |    time_elapsed       | 52         |
# |    total_timesteps    | 328000     |
# | train/                |            |
# |    entropy_loss       | -0.568     |
# |    explained_variance | 0.67526567 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4099       |
# |    policy_loss        | 0.00259    |
# |    value_loss         | 0.000159   |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 437        |
# |    ep_rew_mean        | 437        |
# | time/                 |            |
# |    fps                | 6284       |
# |    iterations         | 4200       |
# |    time_elapsed       | 53         |
# |    total_timesteps    | 336000     |
# | train/                |            |
# |    entropy_loss       | -0.508     |
# |    explained_variance | 0.89572525 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4199       |
# |    policy_loss        | -0.00644   |
# |    value_loss         | 0.000576   |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 458        |
# |    ep_rew_mean        | 458        |
# | time/                 |            |
# |    fps                | 6316       |
# |    iterations         | 4300       |
# |    time_elapsed       | 54         |
# |    total_timesteps    | 344000     |
# | train/                |            |
# |    entropy_loss       | -0.558     |
# |    explained_variance | 0.67691696 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4299       |
# |    policy_loss        | -0.0048    |
# |    value_loss         | 0.00014    |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 468        |
# |    ep_rew_mean        | 468        |
# | time/                 |            |
# |    fps                | 6330       |
# |    iterations         | 4400       |
# |    time_elapsed       | 55         |
# |    total_timesteps    | 352000     |
# | train/                |            |
# |    entropy_loss       | -0.54      |
# |    explained_variance | 0.06411064 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4399       |
# |    policy_loss        | -0.00182   |
# |    value_loss         | 8.12e-05   |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 475        |
# |    ep_rew_mean        | 475        |
# | time/                 |            |
# |    fps                | 6339       |
# |    iterations         | 4500       |
# |    time_elapsed       | 56         |
# |    total_timesteps    | 360000     |
# | train/                |            |
# |    entropy_loss       | -0.613     |
# |    explained_variance | 0.62073493 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4499       |
# |    policy_loss        | 0.00303    |
# |    value_loss         | 0.00011    |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 476       |
# |    ep_rew_mean        | 476       |
# | time/                 |           |
# |    fps                | 6352      |
# |    iterations         | 4600      |
# |    time_elapsed       | 57        |
# |    total_timesteps    | 368000    |
# | train/                |           |
# |    entropy_loss       | -0.506    |
# |    explained_variance | 0.7309487 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4599      |
# |    policy_loss        | -0.00442  |
# |    value_loss         | 0.00041   |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 479        |
# |    ep_rew_mean        | 479        |
# | time/                 |            |
# |    fps                | 6372       |
# |    iterations         | 4700       |
# |    time_elapsed       | 59         |
# |    total_timesteps    | 376000     |
# | train/                |            |
# |    entropy_loss       | -0.541     |
# |    explained_variance | 0.40432018 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4699       |
# |    policy_loss        | -0.000797  |
# |    value_loss         | 5.31e-05   |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 472       |
# |    ep_rew_mean        | 472       |
# | time/                 |           |
# |    fps                | 6392      |
# |    iterations         | 4800      |
# |    time_elapsed       | 60        |
# |    total_timesteps    | 384000    |
# | train/                |           |
# |    entropy_loss       | -0.573    |
# |    explained_variance | 0.5950579 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4799      |
# |    policy_loss        | 0.00144   |
# |    value_loss         | 5.1e-05   |
# -------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 469         |
# |    ep_rew_mean        | 469         |
# | time/                 |             |
# |    fps                | 6388        |
# |    iterations         | 4900        |
# |    time_elapsed       | 61          |
# |    total_timesteps    | 392000      |
# | train/                |             |
# |    entropy_loss       | -0.544      |
# |    explained_variance | -0.40515327 |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4899        |
# |    policy_loss        | -0.000773   |
# |    value_loss         | 2.52e-05    |
# ---------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 477       |
# |    ep_rew_mean        | 477       |
# | time/                 |           |
# |    fps                | 6386      |
# |    iterations         | 5000      |
# |    time_elapsed       | 62        |
# |    total_timesteps    | 400000    |
# | train/                |           |
# |    entropy_loss       | -0.538    |
# |    explained_variance | -3.497747 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4999      |
# |    policy_loss        | 0.000382  |
# |    value_loss         | 4.89e-05  |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 468        |
# |    ep_rew_mean        | 468        |
# | time/                 |            |
# |    fps                | 6394       |
# |    iterations         | 5100       |
# |    time_elapsed       | 63         |
# |    total_timesteps    | 408000     |
# | train/                |            |
# |    entropy_loss       | -0.582     |
# |    explained_variance | 0.20804703 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5099       |
# |    policy_loss        | -0.00378   |
# |    value_loss         | 0.000233   |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 458        |
# |    ep_rew_mean        | 458        |
# | time/                 |            |
# |    fps                | 6429       |
# |    iterations         | 5200       |
# |    time_elapsed       | 64         |
# |    total_timesteps    | 416000     |
# | train/                |            |
# |    entropy_loss       | -0.574     |
# |    explained_variance | 0.35910195 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5199       |
# |    policy_loss        | 0.00247    |
# |    value_loss         | 6.83e-05   |
# --------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 463         |
# |    ep_rew_mean        | 463         |
# | time/                 |             |
# |    fps                | 6447        |
# |    iterations         | 5300        |
# |    time_elapsed       | 65          |
# |    total_timesteps    | 424000      |
# | train/                |             |
# |    entropy_loss       | -0.566      |
# |    explained_variance | -0.12621891 |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5299        |
# |    policy_loss        | -0.00258    |
# |    value_loss         | 6.73e-05    |
# ---------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 469        |
# |    ep_rew_mean        | 469        |
# | time/                 |            |
# |    fps                | 6476       |
# |    iterations         | 5400       |
# |    time_elapsed       | 66         |
# |    total_timesteps    | 432000     |
# | train/                |            |
# |    entropy_loss       | -0.599     |
# |    explained_variance | -1.5638905 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5399       |
# |    policy_loss        | -0.00114   |
# |    value_loss         | 0.000128   |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 461        |
# |    ep_rew_mean        | 461        |
# | time/                 |            |
# |    fps                | 6470       |
# |    iterations         | 5500       |
# |    time_elapsed       | 67         |
# |    total_timesteps    | 440000     |
# | train/                |            |
# |    entropy_loss       | -0.544     |
# |    explained_variance | -1.8495305 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5499       |
# |    policy_loss        | -0.000626  |
# |    value_loss         | 0.000429   |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 451       |
# |    ep_rew_mean        | 451       |
# | time/                 |           |
# |    fps                | 6471      |
# |    iterations         | 5600      |
# |    time_elapsed       | 69        |
# |    total_timesteps    | 448000    |
# | train/                |           |
# |    entropy_loss       | -0.574    |
# |    explained_variance | -0.675025 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5599      |
# |    policy_loss        | 0.00141   |
# |    value_loss         | 0.000172  |
# -------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 450         |
# |    ep_rew_mean        | 450         |
# | time/                 |             |
# |    fps                | 6470        |
# |    iterations         | 5700        |
# |    time_elapsed       | 70          |
# |    total_timesteps    | 456000      |
# | train/                |             |
# |    entropy_loss       | -0.581      |
# |    explained_variance | -0.35048282 |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5699        |
# |    policy_loss        | -0.000587   |
# |    value_loss         | 0.000177    |
# ---------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 450        |
# |    ep_rew_mean        | 450        |
# | time/                 |            |
# |    fps                | 6487       |
# |    iterations         | 5800       |
# |    time_elapsed       | 71         |
# |    total_timesteps    | 464000     |
# | train/                |            |
# |    entropy_loss       | -0.57      |
# |    explained_variance | -0.9282423 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5799       |
# |    policy_loss        | 0.00108    |
# |    value_loss         | 0.000142   |
# --------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 446         |
# |    ep_rew_mean        | 446         |
# | time/                 |             |
# |    fps                | 6490        |
# |    iterations         | 5900        |
# |    time_elapsed       | 72          |
# |    total_timesteps    | 472000      |
# | train/                |             |
# |    entropy_loss       | -0.537      |
# |    explained_variance | 0.008893967 |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5899        |
# |    policy_loss        | -0.00109    |
# |    value_loss         | 6.64e-05    |
# ---------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 447        |
# |    ep_rew_mean        | 447        |
# | time/                 |            |
# |    fps                | 6494       |
# |    iterations         | 6000       |
# |    time_elapsed       | 73         |
# |    total_timesteps    | 480000     |
# | train/                |            |
# |    entropy_loss       | -0.574     |
# |    explained_variance | -2.8360183 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5999       |
# |    policy_loss        | 9.59e-05   |
# |    value_loss         | 0.00018    |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 451       |
# |    ep_rew_mean        | 451       |
# | time/                 |           |
# |    fps                | 6507      |
# |    iterations         | 6100      |
# |    time_elapsed       | 74        |
# |    total_timesteps    | 488000    |
# | train/                |           |
# |    entropy_loss       | -0.573    |
# |    explained_variance | 0.8152827 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6099      |
# |    policy_loss        | -0.0278   |
# |    value_loss         | 0.0341    |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 455        |
# |    ep_rew_mean        | 455        |
# | time/                 |            |
# |    fps                | 6505       |
# |    iterations         | 6200       |
# |    time_elapsed       | 76         |
# |    total_timesteps    | 496000     |
# | train/                |            |
# |    entropy_loss       | -0.595     |
# |    explained_variance | 0.59379077 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6199       |
# |    policy_loss        | -0.00455   |
# |    value_loss         | 0.000116   |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 466        |
# |    ep_rew_mean        | 466        |
# | time/                 |            |
# |    fps                | 6520       |
# |    iterations         | 6300       |
# |    time_elapsed       | 77         |
# |    total_timesteps    | 504000     |
# | train/                |            |
# |    entropy_loss       | -0.575     |
# |    explained_variance | 0.59046054 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6299       |
# |    policy_loss        | -0.00895   |
# |    value_loss         | 0.000792   |
# --------------------------------------
# ----------------------------------------
# | rollout/              |              |
# |    ep_len_mean        | 471          |
# |    ep_rew_mean        | 471          |
# | time/                 |              |
# |    fps                | 6529         |
# |    iterations         | 6400         |
# |    time_elapsed       | 78           |
# |    total_timesteps    | 512000       |
# | train/                |              |
# |    entropy_loss       | -0.556       |
# |    explained_variance | -0.025246143 |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 6399         |
# |    policy_loss        | -0.000256    |
# |    value_loss         | 0.000109     |
# ----------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 472         |
# |    ep_rew_mean        | 472         |
# | time/                 |             |
# |    fps                | 6521        |
# |    iterations         | 6500        |
# |    time_elapsed       | 79          |
# |    total_timesteps    | 520000      |
# | train/                |             |
# |    entropy_loss       | -0.541      |
# |    explained_variance | -0.22155595 |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 6499        |
# |    policy_loss        | -0.00165    |
# |    value_loss         | 7.6e-05     |
# ---------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 472        |
# |    ep_rew_mean        | 472        |
# | time/                 |            |
# |    fps                | 6505       |
# |    iterations         | 6600       |
# |    time_elapsed       | 81         |
# |    total_timesteps    | 528000     |
# | train/                |            |
# |    entropy_loss       | -0.595     |
# |    explained_variance | 0.89606446 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6599       |
# |    policy_loss        | -0.00227   |
# |    value_loss         | 0.000119   |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 482       |
# |    ep_rew_mean        | 482       |
# | time/                 |           |
# |    fps                | 6500      |
# |    iterations         | 6700      |
# |    time_elapsed       | 82        |
# |    total_timesteps    | 536000    |
# | train/                |           |
# |    entropy_loss       | -0.544    |
# |    explained_variance | 0.6965314 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6699      |
# |    policy_loss        | -0.00237  |
# |    value_loss         | 0.000654  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 489       |
# |    ep_rew_mean        | 489       |
# | time/                 |           |
# |    fps                | 6507      |
# |    iterations         | 6800      |
# |    time_elapsed       | 83        |
# |    total_timesteps    | 544000    |
# | train/                |           |
# |    entropy_loss       | -0.563    |
# |    explained_variance | 0.3845827 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6799      |
# |    policy_loss        | -0.00207  |
# |    value_loss         | 6.85e-05  |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 489        |
# |    ep_rew_mean        | 489        |
# | time/                 |            |
# |    fps                | 6520       |
# |    iterations         | 6900       |
# |    time_elapsed       | 84         |
# |    total_timesteps    | 552000     |
# | train/                |            |
# |    entropy_loss       | -0.529     |
# |    explained_variance | 0.31338018 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6899       |
# |    policy_loss        | -0.00138   |
# |    value_loss         | 8.07e-05   |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 489       |
# |    ep_rew_mean        | 489       |
# | time/                 |           |
# |    fps                | 6511      |
# |    iterations         | 7000      |
# |    time_elapsed       | 86        |
# |    total_timesteps    | 560000    |
# | train/                |           |
# |    entropy_loss       | -0.615    |
# |    explained_variance | 0.3689527 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6999      |
# |    policy_loss        | -0.00188  |
# |    value_loss         | 9.38e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 485       |
# |    ep_rew_mean        | 485       |
# | time/                 |           |
# |    fps                | 6502      |
# |    iterations         | 7100      |
# |    time_elapsed       | 87        |
# |    total_timesteps    | 568000    |
# | train/                |           |
# |    entropy_loss       | -0.559    |
# |    explained_variance | 0.4514355 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7099      |
# |    policy_loss        | 0.000123  |
# |    value_loss         | 0.000134  |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 485        |
# |    ep_rew_mean        | 485        |
# | time/                 |            |
# |    fps                | 6500       |
# |    iterations         | 7200       |
# |    time_elapsed       | 88         |
# |    total_timesteps    | 576000     |
# | train/                |            |
# |    entropy_loss       | -0.563     |
# |    explained_variance | 0.27135295 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7199       |
# |    policy_loss        | -0.000729  |
# |    value_loss         | 3.18e-05   |
# --------------------------------------
# -----------------------------------------
# | rollout/              |               |
# |    ep_len_mean        | 482           |
# |    ep_rew_mean        | 482           |
# | time/                 |               |
# |    fps                | 6483          |
# ...
# |    value_loss         | 1.43e-05   |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 484        |
# |    ep_rew_mean        | 484        |
# | time/                 |            |
# |    fps                | 6424       |
# |    iterations         | 10200      |
# |    time_elapsed       | 127        |
# |    total_timesteps    | 816000     |
# | train/                |            |
# |    entropy_loss       | -0.619     |
# |    explained_variance | -0.6286305 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 10199      |
# |    policy_loss        | -0.00156   |
# |    value_loss         | 3.34e-05   |
# --------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 479         |
# |    ep_rew_mean        | 479         |
# | time/                 |             |
# |    fps                | 6412        |
# |    iterations         | 10300       |
# |    time_elapsed       | 128         |
# |    total_timesteps    | 824000      |
# | train/                |             |
# |    entropy_loss       | -0.538      |
# |    explained_variance | -0.17897272 |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 10299       |
# |    policy_loss        | -0.0042     |
# |    value_loss         | 0.000234    |
# ---------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 479      |
# |    ep_rew_mean        | 479      |
# | time/                 |          |
# |    fps                | 6416     |
# |    iterations         | 10400    |
# |    time_elapsed       | 129      |
# |    total_timesteps    | 832000   |
# | train/                |          |
# |    entropy_loss       | -0.607   |
# |    explained_variance | 0.255718 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 10399    |
# |    policy_loss        | -0.00125 |
# |    value_loss         | 2.03e-05 |
# ------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 475        |
# |    ep_rew_mean        | 475        |
# | time/                 |            |
# |    fps                | 6422       |
# |    iterations         | 10500      |
# |    time_elapsed       | 130        |
# |    total_timesteps    | 840000     |
# | train/                |            |
# |    entropy_loss       | -0.585     |
# |    explained_variance | -1.4654872 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 10499      |
# |    policy_loss        | 3.03e-05   |
# |    value_loss         | 2.23e-05   |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 471        |
# |    ep_rew_mean        | 471        |
# | time/                 |            |
# |    fps                | 6426       |
# |    iterations         | 10600      |
# |    time_elapsed       | 131        |
# |    total_timesteps    | 848000     |
# | train/                |            |
# |    entropy_loss       | -0.593     |
# |    explained_variance | -1.8613296 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 10599      |
# |    policy_loss        | -0.000623  |
# |    value_loss         | 3.61e-05   |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 467        |
# |    ep_rew_mean        | 467        |
# | time/                 |            |
# |    fps                | 6420       |
# |    iterations         | 10700      |
# |    time_elapsed       | 133        |
# |    total_timesteps    | 856000     |
# | train/                |            |
# |    entropy_loss       | -0.594     |
# |    explained_variance | -0.3525777 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 10699      |
# |    policy_loss        | -0.00132   |
# |    value_loss         | 3.55e-05   |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 472        |
# |    ep_rew_mean        | 472        |
# | time/                 |            |
# |    fps                | 6427       |
# |    iterations         | 10800      |
# |    time_elapsed       | 134        |
# |    total_timesteps    | 864000     |
# | train/                |            |
# |    entropy_loss       | -0.584     |
# |    explained_variance | 0.11872649 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 10799      |
# |    policy_loss        | -0.00304   |
# |    value_loss         | 7.38e-05   |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 474       |
# |    ep_rew_mean        | 474       |
# | time/                 |           |
# |    fps                | 6438      |
# |    iterations         | 10900     |
# |    time_elapsed       | 135       |
# |    total_timesteps    | 872000    |
# | train/                |           |
# |    entropy_loss       | -0.536    |
# |    explained_variance | 0.3054657 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 10899     |
# |    policy_loss        | -0.00434  |
# |    value_loss         | 0.000134  |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 477        |
# |    ep_rew_mean        | 477        |
# | time/                 |            |
# |    fps                | 6445       |
# |    iterations         | 11000      |
# |    time_elapsed       | 136        |
# |    total_timesteps    | 880000     |
# | train/                |            |
# |    entropy_loss       | -0.594     |
# |    explained_variance | 0.24007404 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 10999      |
# |    policy_loss        | -0.00056   |
# |    value_loss         | 5.56e-05   |
# --------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 477       |
# |    ep_rew_mean        | 477       |
# | time/                 |           |
# |    fps                | 6449      |
# |    iterations         | 11100     |
# |    time_elapsed       | 137       |
# |    total_timesteps    | 888000    |
# | train/                |           |
# |    entropy_loss       | -0.554    |
# |    explained_variance | 0.8965319 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 11099     |
# |    policy_loss        | -0.0137   |
# |    value_loss         | 0.00259   |
# -------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 477         |
# |    ep_rew_mean        | 477         |
# | time/                 |             |
# |    fps                | 6447        |
# |    iterations         | 11200       |
# |    time_elapsed       | 138         |
# |    total_timesteps    | 896000      |
# | train/                |             |
# |    entropy_loss       | -0.556      |
# |    explained_variance | -0.22532904 |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 11199       |
# |    policy_loss        | -0.000324   |
# |    value_loss         | 1.79e-05    |
# ---------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 478       |
# |    ep_rew_mean        | 478       |
# | time/                 |           |
# |    fps                | 6451      |
# |    iterations         | 11300     |
# |    time_elapsed       | 140       |
# |    total_timesteps    | 904000    |
# | train/                |           |
# |    entropy_loss       | -0.6      |
# |    explained_variance | 0.3528546 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 11299     |
# |    policy_loss        | -0.00155  |
# |    value_loss         | 7.58e-05  |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 476        |
# |    ep_rew_mean        | 476        |
# | time/                 |            |
# |    fps                | 6451       |
# |    iterations         | 11400      |
# |    time_elapsed       | 141        |
# |    total_timesteps    | 912000     |
# | train/                |            |
# |    entropy_loss       | -0.609     |
# |    explained_variance | 0.52189195 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 11399      |
# |    policy_loss        | -0.00205   |
# |    value_loss         | 2.85e-05   |
# --------------------------------------
# ----------------------------------------
# | rollout/              |              |
# |    ep_len_mean        | 480          |
# |    ep_rew_mean        | 480          |
# | time/                 |              |
# |    fps                | 6457         |
# |    iterations         | 11500        |
# |    time_elapsed       | 142          |
# |    total_timesteps    | 920000       |
# | train/                |              |
# |    entropy_loss       | -0.56        |
# |    explained_variance | -0.041855812 |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 11499        |
# |    policy_loss        | 0.000645     |
# |    value_loss         | 4.81e-05     |
# ----------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 481       |
# |    ep_rew_mean        | 481       |
# | time/                 |           |
# |    fps                | 6470      |
# |    iterations         | 11600     |
# |    time_elapsed       | 143       |
# |    total_timesteps    | 928000    |
# | train/                |           |
# |    entropy_loss       | -0.637    |
# |    explained_variance | 0.7270944 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 11599     |
# |    policy_loss        | -0.00212  |
# |    value_loss         | 2.18e-05  |
# -------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 486        |
# |    ep_rew_mean        | 486        |
# | time/                 |            |
# |    fps                | 6484       |
# |    iterations         | 11700      |
# |    time_elapsed       | 144        |
# |    total_timesteps    | 936000     |
# | train/                |            |
# |    entropy_loss       | -0.589     |
# |    explained_variance | 0.46816057 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 11699      |
# |    policy_loss        | -0.00201   |
# |    value_loss         | 3.72e-05   |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 488        |
# |    ep_rew_mean        | 488        |
# | time/                 |            |
# |    fps                | 6494       |
# |    iterations         | 11800      |
# |    time_elapsed       | 145        |
# |    total_timesteps    | 944000     |
# | train/                |            |
# |    entropy_loss       | -0.57      |
# |    explained_variance | 0.28344542 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 11799      |
# |    policy_loss        | -0.00137   |
# |    value_loss         | 4.88e-05   |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 483        |
# |    ep_rew_mean        | 483        |
# | time/                 |            |
# |    fps                | 6504       |
# |    iterations         | 11900      |
# |    time_elapsed       | 146        |
# |    total_timesteps    | 952000     |
# | train/                |            |
# |    entropy_loss       | -0.513     |
# |    explained_variance | 0.44510156 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 11899      |
# |    policy_loss        | -0.00351   |
# |    value_loss         | 0.000135   |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 485        |
# |    ep_rew_mean        | 485        |
# | time/                 |            |
# |    fps                | 6517       |
# |    iterations         | 12000      |
# |    time_elapsed       | 147        |
# |    total_timesteps    | 960000     |
# | train/                |            |
# |    entropy_loss       | -0.549     |
# |    explained_variance | -1.2392182 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 11999      |
# |    policy_loss        | -0.000565  |
# |    value_loss         | 0.000113   |
# --------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 485         |
# |    ep_rew_mean        | 485         |
# | time/                 |             |
# |    fps                | 6530        |
# |    iterations         | 12100       |
# |    time_elapsed       | 148         |
# |    total_timesteps    | 968000      |
# | train/                |             |
# |    entropy_loss       | -0.581      |
# |    explained_variance | 0.046879828 |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 12099       |
# |    policy_loss        | -0.00359    |
# |    value_loss         | 7.76e-05    |
# ---------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 482        |
# |    ep_rew_mean        | 482        |
# | time/                 |            |
# |    fps                | 6546       |
# |    iterations         | 12200      |
# |    time_elapsed       | 149        |
# |    total_timesteps    | 976000     |
# | train/                |            |
# |    entropy_loss       | -0.596     |
# |    explained_variance | 0.56298554 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 12199      |
# |    policy_loss        | -0.00521   |
# |    value_loss         | 0.000244   |
# --------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 484         |
# |    ep_rew_mean        | 484         |
# | time/                 |             |
# |    fps                | 6553        |
# |    iterations         | 12300       |
# |    time_elapsed       | 150         |
# |    total_timesteps    | 984000      |
# | train/                |             |
# |    entropy_loss       | -0.561      |
# |    explained_variance | 0.059711397 |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 12299       |
# |    policy_loss        | -0.00176    |
# |    value_loss         | 7.42e-05    |
# ---------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 489        |
# |    ep_rew_mean        | 489        |
# | time/                 |            |
# |    fps                | 6554       |
# |    iterations         | 12400      |
# |    time_elapsed       | 151        |
# |    total_timesteps    | 992000     |
# | train/                |            |
# |    entropy_loss       | -0.558     |
# |    explained_variance | 0.68019617 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 12399      |
# |    policy_loss        | -0.00414   |
# |    value_loss         | 6.26e-05   |
# --------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 496        |
# |    ep_rew_mean        | 496        |
# | time/                 |            |
# |    fps                | 6558       |
# |    iterations         | 12500      |
# |    time_elapsed       | 152        |
# |    total_timesteps    | 1000000    |
# | train/                |            |
# |    entropy_loss       | -0.533     |
# |    explained_variance | -0.6671914 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 12499      |
# |    policy_loss        | -0.00176   |
# |    value_loss         | 0.0001     |
# --------------------------------------

# %% [markdown]
# ##### ¿Comó son las recompensas?
# +1 por cada iteracion que la barra permanece sin caerse
# ##### ¿Comó se si mi modelo aprendió?
# Si la recompensa es grande, pues el modelo recompensa el tiempo que permanece la barra sin caerse (sera el largo maximo de episodio
#
# ### RESPUESTA:
# en este caso una recompensa de 500 es un episodio exitoso

# %% [markdown]
# #### 2.4 Evaluar el agente

# %%
import gymnasium as gym
from stable_baselines3 import A2C
from stable_baselines3.common.vec_env import DummyVecEnv
from gymnasium.wrappers import RecordVideo

# Load the trained model
model = A2C.load("A2C-CartPole-v1")

# Create the environment with the proper render_mode for video recording
env = DummyVecEnv([lambda: RecordVideo(gym.make("CartPole-v1", render_mode="rgb_array"), "./videos/A2C", episode_trigger=lambda x: True)])

# Reset the environment to get the initial observation
obs = env.reset()
done = False

# Play one episode to capture the video
while not done:
    action, _ = model.predict(obs)
    obs, reward, done, info = env.step(action)
    
# Close the environment to save the video file
env.close()

print("Video saved in the './videos' directory.")
# Out:
# MoviePy - Building video /home/mdelcastillo/proyectos/RL-curso/videos/A2C-/rl-video-episode-0.mp4.
# MoviePy - Writing video /home/mdelcastillo/proyectos/RL-curso/videos/A2C-/rl-video-episode-0.mp4
# MoviePy - Done !
# MoviePy - video ready /home/mdelcastillo/proyectos/RL-curso/videos/A2C-/rl-video-episode-0.mp4
# MoviePy - Building video /home/mdelcastillo/proyectos/RL-curso/videos/A2C-/rl-video-episode-1.mp4.
# MoviePy - Writing video /home/mdelcastillo/proyectos/RL-curso/videos/A2C-/rl-video-episode-1.mp4
# MoviePy - Done !
# MoviePy - video ready /home/mdelcastillo/proyectos/RL-curso/videos/A2C-/rl-video-episode-1.mp4
# Video saved in the './videos' directory.
